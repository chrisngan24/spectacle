# %%
# %matplotlib inline
import pandas as pd
import clean

# %%
# Format data
sf = pd.read_csv('data/train.csv')
sf['Date'] = clean.apply_date(sf['Dates'])
sf['Hour'] = clean.apply_hour(sf['Dates'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f0cc2e172aff> in <module>()
#       2 sf = pd.read_csv('data/train.csv')
#       3 sf['Date'] = clean.apply_date(sf['Dates'])
# ----> 4 sf['Hour'] = clean.apply_hour(sf['Dates'])
#
# AttributeError: 'module' object has no attribute 'apply_hour'

# %%
sf.head()
# Out:
#                       Dates                Category  \
# 0       2015-05-13 23:53:00                WARRANTS
# 1       2015-05-13 23:53:00          OTHER OFFENSES
# 2       2015-05-13 23:33:00          OTHER OFFENSES
# 3       2015-05-13 23:30:00           LARCENY/THEFT
# 4       2015-05-13 23:30:00           LARCENY/THEFT
# 5       2015-05-13 23:30:00           LARCENY/THEFT
# 6       2015-05-13 23:30:00           VEHICLE THEFT
# 7       2015-05-13 23:30:00           VEHICLE THEFT
# 8       2015-05-13 23:00:00           LARCENY/THEFT
# 9       2015-05-13 23:00:00           LARCENY/THEFT
# 10      2015-05-13 22:58:00           LARCENY/THEFT
# 11      2015-05-13 22:30:00          OTHER OFFENSES
# 12      2015-05-13 22:30:00               VANDALISM
# 13      2015-05-13 22:06:00           LARCENY/THEFT
# 14      2015-05-13 22:00:00            NON-CRIMINAL
# 15      2015-05-13 22:00:00            NON-CRIMINAL
# 16      2015-05-13 22:00:00                 ROBBERY
# ...

# %% [markdown]
# # Summary/Exploration of Data set

# %%
sf.groupby('Category').count()
# Out:
#                               Dates  Descript  DayOfWeek  PdDistrict  \
# Category
# ARSON                          1513      1513       1513        1513
# ASSAULT                       76876     76876      76876       76876
# BAD CHECKS                      406       406        406         406
# BRIBERY                         289       289        289         289
# BURGLARY                      36755     36755      36755       36755
# DISORDERLY CONDUCT             4320      4320       4320        4320
# DRIVING UNDER THE INFLUENCE    2268      2268       2268        2268
# DRUG/NARCOTIC                 53971     53971      53971       53971
# DRUNKENNESS                    4280      4280       4280        4280
# EMBEZZLEMENT                   1166      1166       1166        1166
# EXTORTION                       256       256        256         256
# FAMILY OFFENSES                 491       491        491         491
# ...

# %%
# %matplotlib inline
sf
