# %%
# Boilerplate at top of file
# %load_ext autoreload
# %load_ext rmagic
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import datetime
import math
import clean

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
from ggplot import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rmagic extension is already loaded. To reload it, use:
#   %reload_ext rmagic

# %%
# Format data
sf = clean.read_and_clean_sf_crim_data_set('data/train.csv')

# %%
# Start finding input signals
sf.head()
sf['Month_int'] = clean.apply_month(sf['Dates'])

# %%
sf.head()
# Out:
#                  Dates        Category                      Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y        Date  Hour  Month      Time  Time_int  \
# 0 -122.425892  37.774599  2015-05-13    23     23  23:53:00     85980
# 1 -122.425892  37.774599  2015-05-13    23     23  23:53:00     85980
# 2 -122.424363  37.800414  2015-05-13    23     23  23:33:00     84780
# 3 -122.426995  37.800873  2015-05-13    23     23  23:30:00     84600
# 4 -122.438738  37.771541  2015-05-13    23     23  23:30:00     84600
#
#    Month_int
# 0          5
# 1          5
# 2          5
# 3          5
# 4          5

# %%
sf = sf[sf['Y'] != 90] # some mislabelled data.
                       # some data points have Y = 90, which makes no
                       # when mapped.

# %%
import statsmodels.api as sm
sf['DayOfWeek_int'] = sm.tools.categorical(sf['DayOfWeek'].values, drop=True).argmax(1)
sf['PdDistrict_int'] = sm.tools.categorical(sf['PdDistrict'].values, drop=True).argmax(1)
sf['Address_int'] = sm.tools.categorical(sf['Address'].values, drop=True).argmax(1)
# sf['Month_int'] = sm.tools.categorical(sf['Month'].values, drop=True).argmax(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b2c2514d2b8e> in <module>()
#       1 import statsmodels.api as sm
# ----> 2 sf['DayOfWeek_int'] = sm.tools.categorical(sf['DayOfWeek'].values, drop=True).argmax(1)
#       3 sf['PdDistrict_int'] = sm.tools.categorical(sf['PdDistrict'].values, drop=True).argmax(1)
#       4 sf['Address_int'] = sm.tools.categorical(sf['Address'].values, drop=True).argmax(1)
#       5 # sf['Month_int'] = sm.tools.categorical(sf['Month'].values, drop=True).argmax(1)
#
# NameError: name 'sf' is not defined

# %%
x = sf[['Time_int', 'X', 'Y', 'DayOfWeek_int','PdDistrict_int','Month_int', 'Address_int']]
y = sf[['Category']]

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x,y)
predict_y = gnb.predict(x)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y['Category'], predict_y)

# %%
# %%R -i predict_y
# table(predict_y)
# Out:
# predict_y
#        ASSAULT  DRUG/NARCOTIC  LARCENY/THEFT   NON-CRIMINAL OTHER OFFENSES
#            611          15699         607757           4556         210439
#   PROSTITUTION      VANDALISM  VEHICLE THEFT
#              7           3774          35139

# %%
print '% accuracy:' + str(np.sum(np.diag(cm)) / float(np.sum(cm)))
# Out:
# % accuracy:0.211751493766

# %%
ggplot(sf, aes(x = 'X', y= 'Y', color = 'Category')) + geom_point()
# Out:
# <ggplot: (307957005)>
